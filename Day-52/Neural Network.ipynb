# %% [markdown]
# ## Perceptron
#
# ![image.png](attachment:dad7d1bb-edbf-464e-967a-ceec478a7857.png)

# %% [markdown]
# ## Multi-layer Preceptron (Neural Network)
#
# ![image.png](attachment:6b74b59c-b0b1-4f2d-84bc-4ba99d6218c4.png)

# %% [markdown]
# ## Forward Propogation
#
#
# ![image.png](attachment:ced4b5d0-677c-4d43-8049-a55a20448086.png)
